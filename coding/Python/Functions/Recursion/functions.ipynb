# %%
# 1. Sum of List Using Recursion
Write a Python program to calculate the sum of a list of numbers using recursion.

# %%
def sum_of_list(l):
    total_sum = 0
    for i in l:
        total_sum += i
    return total_sum


# function call 
l = list(map(int, input("Enter list of values : ").split(',')))
print(sum_of_list(l))
# Out:
# Enter list of values :  1, 2, 3,4,5
# 15

# %%
def sum_of_list(l):
    # first time list 1, 2, 3,4,5
    # second time 2, 3,4,5
    # third time 3,4,5
    # fourth time 4,5
    # fifth time 5
    sum_val = 0
    if len(l) == 1:
        return l[0]

    else:
        return l[0] + sum_of_list(l[1:])



# function call 
l = list(map(int, input("Enter list of values : ").split(',')))
print(sum_of_list(l))
# Out:
# Enter list of values :  1, 2, 3,4,5
# 15

# %%
def sum_of_list(l):
    # Print what the function is currently looking at
    print(f"Opening doll: Current list is {l}")

    # Base Case
    if len(l) == 1:
        print(f"  -> Reached the smallest doll! Returning: {l[0]}")
        return l[0]

    # Recursive Step
    else:
        first_element = l[0]
        remaining_list = l[1:]
        print('remaining_list', remaining_list)
        
        # Call the function again
        result = first_element + sum_of_list(remaining_list)
        
        # Print as the function "returns" or "closes"
        print(f"Closing doll: Adding {first_element} + {result - first_element} = {result}")
        return result

# Function call
user_input = input("Enter list of values (e.g., 1,2,3): ")
l = list(map(int, user_input.split(',')))
print("-" * 30)
final_sum = sum_of_list(l)
print("-" * 30)
print(f"Final Sum: {final_sum}")
# Out:
# Enter list of values (e.g., 1,2,3):  1, 2, 3,4,5
# ------------------------------
# Opening doll: Current list is [1, 2, 3, 4, 5]
# remaining_list [2, 3, 4, 5]
# Opening doll: Current list is [2, 3, 4, 5]
# remaining_list [3, 4, 5]
# Opening doll: Current list is [3, 4, 5]
# remaining_list [4, 5]
# Opening doll: Current list is [4, 5]
# remaining_list [5]
# Opening doll: Current list is [5]
#   -> Reached the smallest doll! Returning: 5
# Closing doll: Adding 4 + 5 = 9
# Closing doll: Adding 3 + 9 = 12
# Closing doll: Adding 2 + 12 = 14
# Closing doll: Adding 1 + 14 = 15
# ------------------------------
# Final Sum: 15

# %%
# 2.  Integer to String Conversion in Any Base Using Recursion
# Write a Python program to convert an integer to a string in any base using recursion .

# Define a function named to_string that converts a number 'n' to a string representation
# in a given 'base' using a character set "0123456789ABCDEF"
def to_string(n, base):
    # Define a character set for the conversion in hexadecimal format
    conver_tString = "0123456789ABCDEF"
    
    # Check if the number 'n' is less than the specified base
    if n < base:
        # If 'n' is less than the base, return the corresponding character from the character set
        return conver_tString[n]
    else:
        # If 'n' is greater than or equal to the base, recursively call the to_string function
        # to convert the quotient (n // base) to a string and concatenate it with the remainder
        # (n % base) represented in the character set
        return to_string(n // base, base) + conver_tString[n % base]

# Print the result of calling the to_string function with the input values 2835 and 16
print(to_string(2835, 16))
# Out:
# B13

# %%
# Sum of Nested Lists Using Recursion
# Write a Python program to sum recursion lists using recursion.

# Test Data: [1, 2, [3,4], [5,6]]
# Expected Result: 21

def Nested_Lists_Sum(l):
    l1 = []
    for i in l:
        if isinstance(i, list):
            for j in i:
                l1.append(j)
        else:
            l1.append(i)

    return l1


print(Nested_Lists_Sum([1, 2, [3,4], [5,6]]))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Factorial Using Recursion
# Write a Python program to get the factorial of a non-negative integer using recursion.
def factorial(n):
    if n == 1:
        return 1

    else:
        return n * factorial(n-1)

print(factorial(5))
# Out:
# 120

# %%
def gcd(a, b):
    if b == 0:
        return a
    return gcd(b, a % b)


print(gcd(18, 12))
# Out:
# 6

# %%
# Fibonacci Sequence Using Recursion
# Write a Python program to solve the Fibonacci sequence using recursion.

def fibonacci_sequence(n):
    if n == 1:
        return [0]
    if n == 2:
        return [0, 1]

    seq = fibonacci_sequence(n-1)
    seq.append(seq[-1] + seq[-2])
    return seq

print(fibonacci_sequence(5))
# Out:
# [0, 1, 1, 2, 3]
