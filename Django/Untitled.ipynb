# %%
1. what is djnago why we use it 
2. what is wsgi how its works 
3. what is asgi

# %%
 aggregate and annonate 

aggregate via using we will get average as in dict 
by using annonate we will get each and every count how many 

from django.db.models import Count, AVG
authors = Author.objects.annotate(num_books=Count('book'))
avg_price = Book.objects.aggregate(avg_price=AVG('price'))
