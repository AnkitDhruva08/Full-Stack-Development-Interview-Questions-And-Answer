# %%
# !pip install openai datasets evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.6/660.6 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 13.1 MB/s eta 0:00:0031m13.5 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 21.0 MB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 19.0.0
#     Uninstalling pyarrow-19.0.0:
#       Successfully uninstalled pyarrow-19.0.0
#   Attempting uninstall: dillm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/10 [pyarrow]
#     Found existing installation: dill 0.3.838;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━  4/10 [dill]
#     Uninstalling dill-0.3.8:━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━  4/10 [dill]
#       Successfully uninstalled dill-0.3.8;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━  4/10 [dill]
# ...
